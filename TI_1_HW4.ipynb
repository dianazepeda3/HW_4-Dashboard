# %% [markdown]
# # Homework 4
#
# **Name:** -- Diana Zepeda Tatengo --
#
# **e-mail:** -- diana.zepeda6085@alumnos.udg.mx --

# %% [markdown]
# # MODULES

# %%
# Load modules
import numpy as np
import matplotlib.pyplot as plt
import math

from scipy.stats import wrapcauchy
from scipy.stats import levy_stable
from scipy.stats import exponweib
from scipy.spatial import distance

import plotly.graph_objects as go
import pandas as pd

import panel as pn
pn.extension()

import panel.widgets as pnw
import hvplot.pandas
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='5ebbd182-6760-4143-921a-1ff12d97bbb9'>
#   <div id="dc366043-d348-46ff-a823-c2c5526327fb" data-root-id="5ebbd182-6760-4143-921a-1ff12d97bbb9" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"1fe8f657-da7a-4b03-9b31-e14da6db53fc":{"version":"3.6.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"5ebbd182-6760-4143-921a-1ff12d97bbb9"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"1a10b240-220d-485d-80ee-2adace233362","attributes":{"plot_id":"5ebbd182-6760-4143-921a-1ff12d97bbb9","comm_id":"9ad4ab8c410549dc9b0d1e771fdc24f5","client_comm_id":"5f19fbd8ccbf43cdb5087338a7bbf308"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"1fe8f657-da7a-4b03-9b31-e14da6db53fc","roots":{"5ebbd182-6760-4143-921a-1ff12d97bbb9":"dc366043-d348-46ff-a823-c2c5526327fb"},"root_ids":["5ebbd182-6760-4143-921a-1ff12d97bbb9"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# # CLASSES

# %%
################# http://www.pygame.org/wiki/2DVectorClass ##################
class Vec2d(object):
    """2d vector class, supports vector and scalar operators,
       and also provides a bunch of high level functions
       """
    __slots__ = ['x', 'y']

    def __init__(self, x_or_pair, y = None):
        if y == None:            
            self.x = x_or_pair[0]
            self.y = x_or_pair[1]
        else:
            self.x = x_or_pair
            self.y = y
            
    # Addition
    def __add__(self, other):
        if isinstance(other, Vec2d):
            return Vec2d(self.x + other.x, self.y + other.y)
        elif hasattr(other, "__getitem__"):
            return Vec2d(self.x + other[0], self.y + other[1])
        else:
            return Vec2d(self.x + other, self.y + other)

    # Subtraction
    def __sub__(self, other):
        if isinstance(other, Vec2d):
            return Vec2d(self.x - other.x, self.y - other.y)
        elif (hasattr(other, "__getitem__")):
            return Vec2d(self.x - other[0], self.y - other[1])
        else:
            return Vec2d(self.x - other, self.y - other)

    # Multiplication
    def __mul__(self, scalar):
        return Vec2d(self.x * scalar, self.y * scalar)
    
    # Vector length
    def get_length(self):
        return math.sqrt(self.x**2 + self.y**2)
    
    # rotate vector
    def rotated(self, angle):        
        cos = math.cos(angle)
        sin = math.sin(angle)
        x = self.x*cos - self.y*sin
        y = self.x*sin + self.y*cos
        return Vec2d(x, y)

# %% [markdown]
# # FUNCTIONS

# %%
#############################
# Brownian motion trajectoy #
#############################
def bm_2d(n_steps=1000, speed=5, s_pos=[0,0]):
    """
    Arguments:
        n_steps: int, number of steps in the simulation (default is 1000).
        speed: float, magnitude of the step in each iteration (default is 5).
        s_pos: list, initial position [x, y] (default is [0,0]).
    Returns:
        BM_2d_df: returns a DataFrame containing the 2D positions at each step
    """
    # Init velocity vector
    velocity = Vec2d(speed,0)
    
    # Init DF
    BM_2d_df = pd.DataFrame(columns=['x_pos','y_pos'])    
    # Add initial position
    temp_df = pd.DataFrame([{'x_pos':s_pos[0], 'y_pos':s_pos[1]}])    
    BM_2d_df = pd.concat([BM_2d_df, temp_df], ignore_index=True)
    
    # Generate the trajectory
    for i in range(n_steps-1):        
        turn_angle = np.random.uniform(low=-np.pi, high=np.pi)
        velocity = velocity.rotated(turn_angle)
    
        temp_df = pd.DataFrame([{'x_pos':BM_2d_df.x_pos[i]+velocity.x, 'y_pos':BM_2d_df.y_pos[i]+velocity.y}])    
        BM_2d_df = pd.concat([BM_2d_df, temp_df], ignore_index=True)
        
    return BM_2d_df
####################################
# Correlated Random Walk trajectoy #
####################################
def CRW_2d(n_steps=1000, speed=5, s_pos=[0,0], cauchy=0.5):
    """
    Arguments:
        n_steps: int, number of steps in the simulation (default is 1000).
        speed: float, magnitude of the step in each iteration (default is 5).
        s_pos: list, initial position [x, y] (default is [0,0]).
        cauchy: float, alpha value to get the turn_angle from cauchy (default is 0.5)
    Returns:
        CRW_2d: returns a DataFrame containing the 2D positions at each step
    """
    # Init velocity vector
    velocity = Vec2d(speed,0)
    
    # Init DF
    CRW_2d = pd.DataFrame(columns=['x_pos','y_pos'])
    
    # Add initial position
    temp_df = pd.DataFrame([{'x_pos':s_pos[0], 'y_pos':s_pos[1]}])
    
    CRW_2d = pd.concat([CRW_2d, temp_df], ignore_index=True)
    
    # Generate the trajectory
    for i in range(n_steps-1):   
        turn_angle = wrapcauchy.rvs(cauchy) # rvs gets random values from the distribution
        velocity = velocity.rotated(turn_angle)
    
        temp_df = pd.DataFrame([{'x_pos':CRW_2d.x_pos[i]+velocity.x, 'y_pos':CRW_2d.y_pos[i]+velocity.y}])    
        CRW_2d = pd.concat([CRW_2d, temp_df], ignore_index=True)
        
    return CRW_2d

###############
# Path Length #
###############
def path_length(trajectory):
    """
    Calculate the total path length of a given trajectory.
    
    Parameters:
    trajectory: A pandas DataFrame containing the trajectory
    
    Returns:
    path_length: A numpy array containing the cumulative sum of the distances
    """
    # Get the Euclidean Distance
    distances = np.array([distance.euclidean(trajectory.iloc[i-1], trajectory.iloc[i]) for i in range(1, trajectory.shape[0])])
    # Get the Cumulative Sum of the stephs
    return np.cumsum(distances)

#############################
# Mean Squared Displacement #
#############################
def msd(trajectory):
    """
    Compute the Mean Squared Displacement (MSD) for a given trajectory.
    
    Parameters:
    trajectory: A numpy array containing the trajectory
    
    Returns:
    msd: The MSD as a function of time.
    """
    N = len(trajectory)    
    msd = np.zeros(N-1)
    
    for i in range(1,N):
        displacements = trajectory[i:] - trajectory[:N - i]
        squared_displacements = np.sum(displacements**2, axis=1) # Square each coordinate of the displacement and add them together
        msd[i-1] = np.mean(squared_displacements) # Save the msd
    
    return msd

####################################
#  Get the angles between vectors  #
####################################
def trajectory_angles(trajectory):
    """
    Compute the Turning Angles for a given trajectory.
    
    Parameters:
    trajectory: A pandas DataFrame containing the trajectory
    
    Returns:
    angles: A pandas Series containing the angles
    """
    angles = []

    for i in range(1, len(trajectory) - 1):
        # Get Vectors
        V1 = np.array(trajectory.iloc[i] - trajectory.iloc[i - 1]) # v(i) - v(i-1)
        V2 = np.array(trajectory.iloc[i + 1] - trajectory.iloc[i]) # v(i+1) - v(i)  
        
        # Dot Product
        dot_product = np.dot(V1, V2)
        
        # Vector magnitudes
        norm_V1 = np.linalg.norm(V1)
        norm_V2 = np.linalg.norm(V2)
        
        # Avoid div by 0
        if norm_V1 == 0 or norm_V2 == 0:
            angles.append(0)
            continue
        
        # Calculate the angle     
        cos_theta = dot_product / (norm_V1 * norm_V2)        
                
        theta = np.arccos(cos_theta)  # Cos -1  get angles on [0, 2π]

        # Convert V1 and V2 to 3D (to apply the cross product)
        V1_3D = np.array([V1[0], V1[1], 0], dtype=np.float64)
        V2_3D = np.array([V2[0], V2[1], 0], dtype=np.float64)
        
        # Calculate the cross product in 3D to determine the sign of the angle
        cross_product = np.cross(V1_3D, V2_3D)[-1]
        
        # If cross product is negative, the angle is negative
        if cross_product < 0:
            theta = -theta            
        
        angles.append(theta)  
    
    return pd.Series(angles)

###############
#  Lévy Walk  #
###############
def LevyW_2d(n_steps=1000, speed=5, s_pos=[0,0], alpha=1, beta=1, cauchy=0.7, loc=1):
    """
    Arguments:
        n_steps: int, number of steps in the simulation (default is 1000).
        speed: float, magnitude of the step in each iteration (default is 5).
        s_pos: list, initial position [x, y] (default is [0,0]).
        alpha: float, the stability parameter for the Lévy distribution (default is 1).
        beta: float, the skewness parameter for the Lévy distribution (default is 1).
        cauchy: float, the parameter controlling the dispersion of the Cauchy distribution for the turn angle (default is 0.7).
    Returns:
        Levy_2d: returns a DataFrame containing the 2D positions at each step
    """
    # Init velocity vector
    velocity = Vec2d(speed,0)
    
    # Init DF
    Levy_2d = pd.DataFrame(columns=['x_pos','y_pos'])
    
    # Add initial position
    temp_df = pd.DataFrame([{'x_pos':s_pos[0], 'y_pos':s_pos[1]}])
    
    Levy_2d = pd.concat([Levy_2d, temp_df], ignore_index=True)
    
    # Generate the trajectory
    for i in range(n_steps-1):   
        # Choose a random angle from cauchy distribution
        turn_angle = wrapcauchy.rvs(cauchy)
    
        # Generate step length from lévy distribution
        step_length = levy_stable.rvs(alpha,beta,loc=loc) #loc 1 to get only positive values
    
        velocity = velocity.rotated(turn_angle)
    
        # Calculate the displacement
        displacement = velocity * step_length
    
        temp_df = pd.DataFrame([{'x_pos':Levy_2d.x_pos[i]+displacement.x, 'y_pos':Levy_2d.y_pos[i]+displacement.y}])           
        Levy_2d = pd.concat([Levy_2d, temp_df], ignore_index=True)
        
    return Levy_2d

#################
#  Step Length  #
#################
def step_length(trajectory):
    """
    Calculates the step lengths from a trajectory.

    Parameters:
    trajectory: pandas DataFrame with 'x_pos' and 'y_pos' columns representing positions.

    Returns:
    step_lengths: A pandas Series representing the length of each step.
    """
    # Calculate the step lengths between consecutive positions using Euclidean distance
    step_lengths = np.array([distance.euclidean(trajectory.iloc[i-1], trajectory.iloc[i]) for i in range(1, trajectory.shape[0])])   
    
    return pd.Series(step_lengths)

# %% [markdown]
# # WIDGETS

# %%
Radio_Button = pnw.RadioButtonGroup(name='Radio Button Group', width=340, options=['BM','CRW', 'LF'])
n_steps = pnw.IntSlider(name='Number of steps', width=340, value=100, step=100, start=10, end=1000)
s_x_pos = pnw.IntInput(name='Starting pos_x', width=160, value=0, step=1, start=-100, end=100)
s_y_pos = pnw.IntInput(name='Starting pos_y', width=160, value=0, step=1, start=-100, end=100)
s_pos = pn.Row(s_x_pos,s_y_pos)
speed = pnw.IntSlider(name="speed", width=340, value=6, start=0, end=10)
metrics = pnw.Select(name="Metrics", width=340, value="PL", options=["PL", "MSD", "TAD"])
cauchy = pnw.FloatInput(name='Cauchy coefficient', width=160, value=0.5, step=0.1, start=0.1, end=0.9, format="0.0")
alpha = pnw.FloatInput(name='Alpha α', width=160, value=1, step=0.1, start=0.1, end=2, format="0.0")
location = pnw.IntSlider(name='Location', width=340, value=0, step=1, start=0, end=10)

# %%
@pn.depends(Radio_Button)
def display_radio_button(Radio_Button):
    if Radio_Button == "CRW":
        return pn.Column(n_steps, s_pos, speed, cauchy, metrics)
    elif Radio_Button == "LF":
        return pn.Column(n_steps, s_pos, speed, pn.Row(cauchy,alpha), location, metrics)
        
    return pn.Column(n_steps, s_pos, speed, metrics)

# %% [markdown]
# # PANEL

# %%
# Template
a=pn.template.MaterialTemplate(
    site="HW 4",
    title="Dashboard",
      sidebar=[pn.Column(Radio_Button, display_radio_button)]
)

# %%
server = a.show(port=5006)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 server = a.show(port=5006)
#
# File ~\OneDrive\Escritorio\VirtualEnviroments\hw1_mcap\Lib\site-packages\panel\viewable.py:470, in ServableMixin.show(self, title, port, address, websocket_origin, threaded, verbose, open, location, **kwargs)
#     432 def show(
#     433     self, title: str | None = None, port: int = 0, address: str | None = None,
#     434     websocket_origin: str | None = None, threaded: bool = False, verbose: bool = True,
#     435     open: bool = True, location: bool | Location = True, **kwargs
#     436 ) -> StoppableThread | Server:
#     437     """
#     438     Starts a Bokeh server and displays the Viewable in a new tab.
#     439
#    (...)
#     468       was launched on (if threaded=True)
#     469     """
# --> 470     return serve(
#     471         self, port=port, address=address, websocket_origin=websocket_origin,
#     472         show=open, start=True, title=title, verbose=verbose,
#     473         location=location, threaded=threaded, **kwargs
#     474     )
#
# File ~\OneDrive\Escritorio\VirtualEnviroments\hw1_mcap\Lib\site-packages\panel\io\server.py:812, in serve(panels, port, address, websocket_origin, loop, show, start, title, verbose, location, threaded, admin, **kwargs)
#     810     server.start()
#     811 else:
# --> 812     return get_server(panels, **kwargs)
#     813 return server
#
# File ~\OneDrive\Escritorio\VirtualEnviroments\hw1_mcap\Lib\site-packages\panel\io\server.py:1106, in get_server(panel, port, address, websocket_origin, loop, show, start, title, verbose, location, admin, static_dirs, basic_auth, oauth_provider, oauth_key, oauth_secret, oauth_redirect_uri, oauth_extra_params, oauth_error_template, cookie_secret, oauth_encryption_key, oauth_jwt_user, oauth_refresh_tokens, oauth_guest_endpoints, oauth_optional, root_path, login_endpoint, logout_endpoint, login_template, logout_template, session_history, liveness, warm, **kwargs)
#    1103         state.base_url = root_path  # type: ignore
#    1104 opts['cookie_secret'] = config.cookie_secret
# -> 1106 server = Server(apps, port=port, **opts)
#    1107 if verbose:
#    1108     address = server.address or 'localhost'
#
# File ~\OneDrive\Escritorio\VirtualEnviroments\hw1_mcap\Lib\site-packages\panel\io\server.py:321, in Server.__init__(self, *args, **kwargs)
#     320 def __init__(self, *args, **kwargs):
# --> 321     super().__init__(*args, **kwargs)
#     322     self._autoreload_stop_event = None
#     323     if state._admin_context:
#
# File ~\OneDrive\Escritorio\VirtualEnviroments\hw1_mcap\Lib\site-packages\bokeh\server\server.py:430, in Server.__init__(self, applications, io_loop, http_server_kwargs, **kwargs)
#     428         extra_websocket_origins = []
#     429 else:
# --> 430     sockets, self._port = bind_sockets(opts.address, opts.port)
#     431     self._address = opts.address
#     433     extra_websocket_origins = create_hosts_allowlist(opts.allow_websocket_origin, self.port)
#
# File ~\OneDrive\Escritorio\VirtualEnviroments\hw1_mcap\Lib\site-packages\bokeh\server\util.py:68, in bind_sockets(address, port)
#      48 def bind_sockets(address: str | None, port: int) -> tuple[list[socket], int]:
#      49     ''' Bind a socket to a port on an address.
#      50
#      51     Args:
#    (...)
#      66
#      67     '''
# ---> 68     ss = netutil.bind_sockets(port=port or 0, address=address)
#      69     assert len(ss)
#      70     ports = {s.getsockname()[1] for s in ss}
#
# File ~\OneDrive\Escritorio\VirtualEnviroments\hw1_mcap\Lib\site-packages\tornado\netutil.py:162, in bind_sockets(port, address, family, backlog, flags, reuse_port)
#     160 sock.setblocking(False)
#     161 try:
# --> 162     sock.bind(sockaddr)
#     163 except OSError as e:
#     164     if (
#     165         errno_from_exception(e) == errno.EADDRNOTAVAIL
#     166         and address == "localhost"
#    (...)
#     178         # might be a real problem like a typo in a
#     179         # configuration.
#
# OSError: [WinError 10048] Solo se permite un uso de cada dirección de socket (protocolo/dirección de red/puerto)

# %%
server.stop()
del server  # Elimina la referencia para evitar conflictos
server = a.show(port=5006)
# Out:
# Launching server at http://localhost:5006
# WARNING:root:Dropping a patch because it contains a previously known reference (id='abdeaa6b-6eba-4f38-acd2-6bdc899bd2b6'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='a9c01b9a-7dfb-441e-8992-fc62f0a8928e'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='dbc32af5-d367-44fb-ba73-65d4e1876450'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='116a0669-3d7a-49c9-85a9-7da325f828da'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='686eb729-1c3c-41d0-a16d-b7c385f6f139'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='93389ae7-44df-4ee0-a67f-6c235a3868f5'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='ac2373a6-e8c7-4f0f-a61b-182d45393cdc'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='966037e0-21eb-4f3e-b6e7-5bf40550f8f0'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='53223d9e-3fa0-4033-9eb2-d53ea19c7677'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='7df86014-669d-4d61-9424-806aa9caa01f'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='2d20a1c8-9347-4e1a-acb7-de8b11fd8a14'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='b7da01cc-1bea-436b-8751-d7541a420d4a'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='b5ace199-cb3f-4a3b-bd6a-41f68a1c64b2'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='d386717b-32e7-43d4-9c86-e38b93d3a630'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='599694d9-6c99-4afe-baf0-c3b2d52c8f07'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='b9c94df9-ff18-4c3b-ad36-6e736556ce83'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='38cfffb9-30b8-4821-86b1-313ce290be8b'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='807c5e2b-3f14-435e-9f0e-394fc7e1c94f'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='3b30f07e-1b6b-4241-9831-59231a7fd971'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='06ba9886-fdee-499b-a39c-37858c00753a'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='707a388b-1ff3-411c-8553-1072efa8fa48'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='d4d10def-61d4-4698-8d3d-f9a0d9f159f9'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='988a7db6-18a9-4112-bedf-72e60c2d2fab'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='884fcc58-3db1-49cc-9688-3bea6e27d572'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='9c4edfb9-c08c-449d-b3e4-65c010e2e54b'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='eef94864-da08-43da-8dcc-45893e667a59'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='7aed9086-f5b9-429c-bf6f-1f82075a2017'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='a74a1810-1f73-42d0-a3bf-1914018ad235'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='ba9b8487-5b82-424f-9e67-27f923f7ba0a'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='54f3ea85-856a-401d-ace7-3726e43e55f0'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='13c43ac6-c642-4c31-9bc4-f35b3217b6f4'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='2d7cb0f4-ce29-45ce-9c37-b12c2485c6c3'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='3bb25ed2-5011-49b2-90a6-f17759f15ad7'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='3f013bae-a0e5-4126-a9d8-19c92e8d8e33'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='eaa1cf1a-f347-4736-9a9e-98d0b620d06c'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='33308540-309c-4610-9090-61694b63f3af'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='7beedc2a-9fa1-4473-9428-d9875810a6f7'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='a8b458ee-cd6f-4583-a422-e6f4e0a34544'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='06b2df09-7db3-4013-ac79-71ac66f853b8'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='0581b50c-9bdc-4d1c-96fd-13e59669f871'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='b57d117e-97f3-44de-bd4f-bc8c5e2b11c1'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='5d2973f2-8702-415e-a2da-e08190a8b33d'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='cdf1b492-47cf-45cb-8157-2fadf0331b53'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='4dbd3bf3-7eae-4059-9f91-82e44ee71724'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='2a139d7d-ea21-4879-bb70-96be7b23f413'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='abd5d6b9-0b69-41fe-9d27-78c2d104998a'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='5c86ea0d-16b7-4be1-99b3-4d7d9a4cda85'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='3cedb20f-987e-4878-b5b8-21bda7a11a1a'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='8a3841eb-eaae-48cb-b563-8771fbb499fb'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='cb3fe214-6507-4d52-a8f3-9b745a0a5aef'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='1339e6fa-fc12-4ecc-8172-cfc83d01460b'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='567e5d5c-64af-4146-9d0d-7fbdf531da16'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='a43e5ff8-978d-4b5d-bdcc-ba6b340ab098'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='d2fae358-881a-44d3-af44-79a0e81ef7d9'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='1426c5ba-a1f7-4f3e-9cad-503d93dde815'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='90de0202-3162-402b-9522-8b4bc010d663'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='02ea99ce-846f-4140-b871-3869ea9e022e'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='343aa932-c0c6-4365-a9cd-4951c96bf833'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='44ef89b6-e357-41f6-9c6f-0485302fe857'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='08095b1b-6857-400f-b442-703bfcf4ccfb'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='a14b56e6-6ce8-4c07-a0f1-6bde3a6a7dfa'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='98b66c90-95da-4fa7-9484-20d84a267840'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='6464acd9-8cfb-4c2f-a0d9-4cb27fb49f11'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='4ec38a9b-8afb-4957-93e9-03dd25292774'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='789896cd-873f-42c4-9f39-1785e2fe497f'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='9ac4bbd0-40d1-43ef-adc0-3a318f3c8df7'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='44f1822e-d823-4990-ade9-b98b80ee50c3'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='3ba583d7-4375-4c26-ad09-7c108af99b40'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='c352c2f4-05b1-4888-a8a0-7e3731141dbb'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='f4bf7670-ddf6-4147-bc12-92e92f412041'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
